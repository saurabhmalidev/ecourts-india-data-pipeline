# %%
# %sql
CREATE DATABASE IF NOT EXISTS ecourts_gold;

CREATE TABLE IF NOT EXISTS ecourts_gold.gold_summary
USING DELTA
LOCATION 'abfss://gold@saadlsecourtsindia.dfs.core.windows.net/gold_summary/';

CREATE TABLE IF NOT EXISTS ecourts_gold.gold_age_distribution
USING DELTA
LOCATION 'abfss://gold@saadlsecourtsindia.dfs.core.windows.net/gold_age_distribution/';

CREATE TABLE IF NOT EXISTS ecourts_gold.gold_subtype_breakdown
USING DELTA
LOCATION 'abfss://gold@saadlsecourtsindia.dfs.core.windows.net/gold_subtype_breakdown/';
